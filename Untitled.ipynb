# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from datetime import datetime
import os

# we are trying to make this portable

home = os.environ['HOME']

# home = os.expanduser('~')

# %%
home
# Out:
# '/home/neuralcrypto'

# %%
# There are 2 ways of dealing with paths in python, os and pathlib

# %%
data_path = os.path.join(home, 'dkb-data', 'raw', 'cdn_20200117-20200123.log')

# %%
os.listdir(os.path.join(home, 'dkb-data', 'raw'))
# Out:
# ['cdn_20200117-20200123.log']

# %%
data_path
# Out:
# '/home/neuralcrypto/dkb-data/raw/cdn_20200117-20200123.log'

# %%
from data_functions import loader_raw_lines

# %%
data = loader_raw_lines(data_path,n_lines=100_000)

# %%
pd.set_option("display.max_columns", 60)

# %%
data.head()
# Out:
#   CacheCacheStatus  CacheResponseBytes  CacheResponseStatus  CacheTieredFill  \
# 0          unknown                1503                  301            False
# 1          unknown                   0                    0            False
# 2          unknown               21107                  200            False
# 3          unknown                1682                  200            False
# 4          unknown                   0                    0            False
#
#    ClientASN ClientCountry ClientDeviceType                          ClientIP  \
# 0       6805            de           mobile  95479cf98782059cef06eb8017adfb0f
# 1       6805            de           mobile  95479cf98782059cef06eb8017adfb0f
# 2       6805            de           mobile  95479cf98782059cef06eb8017adfb0f
# 3       8447            at           mobile  4a6e8b820b8569a50d394a6061b00034
# 4       6805            de           mobile  95479cf98782059cef06eb8017adfb0f
#
# ...

# %%
data.ClientRequestUserAgent.nunique()
# Out:
# 299

# %%
data.groupby('ClientDeviceType').mean()
# Out:
#                   CacheResponseBytes  CacheResponseStatus  CacheTieredFill  \
# ClientDeviceType
# mobile                   8921.673366           210.254842         0.000066
# tablet                  35988.863966           210.653022         0.000055
#
#                      ClientASN  ClientRequestBytes  ClientSrcPort  EdgeColoID  \
# ClientDeviceType
# mobile            12989.488481         3147.153688   35497.170779   67.987707
# tablet            17552.154565         4035.313275   33973.837018   65.738302
#
#                   EdgeRateLimitID  EdgeResponseBytes  \
# ClientDeviceType
# mobile                        0.0        7612.802910
# tablet                        0.0       34735.239041
#
#                   EdgeResponseCompressionRatio  EdgeResponseStatus  \
# ClientDeviceType
# mobile                                1.396833          225.194304
# tablet                                1.322258          213.290198
#
# ...

# %%
data.ClientRequestPath.value_counts().head(50)
# Out:
# /dkbDtMonSrv                                                                                                       25207
# /binary-content.xhtml                                                                                              11074
# /DkbTransactionBanking/content/service/Secure3D/DynConfirmationPopup.xhtml                                          8716
# /dkb/LoadSelections                                                                                                 7602
# /LoadSelections                                                                                                     7470
# /favicon.ico                                                                                                        6087
# /banking                                                                                                            4856
# /DkbTransactionBanking/content/banking/financialstatus/FinancialComposite/FinancialStatus.xhtml                     3958
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100001 entries, 0 to 100000
# Data columns (total 59 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CacheCacheStatus                100001 non-null  object
#  1   CacheResponseBytes              100001 non-null  int64
#  2   CacheResponseStatus             100001 non-null  int64
#  3   CacheTieredFill                 100001 non-null  bool
#  4   ClientASN                       100001 non-null  int64
#  5   ClientCountry                   100001 non-null  object
#  6   ClientDeviceType                100001 non-null  object
#  7   ClientIP                        100001 non-null  object
#  8   ClientIPClass                   100001 non-null  object
#  9   ClientRequestBytes              100001 non-null  int64
#  10  ClientRequestHost               100001 non-null  object
#  11  ClientRequestMethod             100001 non-null  object
# ...

# %%
data.describe()
# Out:
#        CacheResponseBytes  CacheResponseStatus      ClientASN  \
# count        1.000010e+05        100001.000000  100001.000000
# mean         2.374704e+04           210.472935   15488.572584
# std          6.512332e+04            45.890112   31810.212947
# min          0.000000e+00             0.000000      25.000000
# 25%          1.448000e+03           200.000000    3209.000000
# 50%          1.730000e+03           200.000000    6805.000000
# 75%          1.698500e+04           200.000000    8881.000000
# max          2.281240e+06           406.000000  264609.000000
#
#        ClientRequestBytes  ClientSrcPort     EdgeColoID  EdgeRateLimitID  \
# count       100001.000000  100001.000000  100001.000000         100001.0
# mean          3633.620474   34662.803522      66.755652              0.0
# std           2570.017913   19127.093654      17.797427              0.0
# min           1956.000000    1037.000000       4.000000              0.0
# ...

# %%
data.loc[:, 'OriginResponseTime'].hist()

# %%
target = data.loc[:, 'OriginResponseTime'].to_frame()
# or  data.loc[:, '[OriginResponseTime']]

import numpy as np
target.loc[:,'log-target'] = np.log10(data.loc[:,'OriginResponseTime'] + 1e-23)


target.sort_values(by='OriginResponseTime')
# Out:
#        OriginResponseTime  log-target
# 72593                   0  -23.000000
# 20999                   0  -23.000000
# 20997                   0  -23.000000
# 20996                   0  -23.000000
# 74874                   0  -23.000000
# ...                   ...         ...
# 99178         28717000000   10.458139
# 98874         28917000000   10.461153
# 98438         32769000000   10.515463
# 99108         43430000000   10.637790
# 99085         47384000000   10.675632
#
# [100001 rows x 2 columns]

# %%
target.hist('log-target', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bee524710>]],
#       dtype=object)

# %%
from data_functions import create_target_report

# %%
create_target_report(target, 'log-target')

# %%
from data_functions import create_target_report

# %%
create_target_report(target, 'log-target')

# %%
mask = target.loc[:, 'OriginResponseTime'] != 0

no_zeros = target.loc[mask, :]
no_zeros.loc[:, 'target-no-zeros'] = no_zeros.loc[:, 'OriginResponseTime']
# Out:
# /home/neuralcrypto/anaconda3/envs/dkb/lib/python3.7/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/neuralcrypto/anaconda3/envs/dkb/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
create_target_report(no_zeros, 'target-no-zeros')

# %%
no_zeros
# Out:
#         OriginResponseTime  log-target  target-no-zeros
# 0                 18000000    7.255273         18000000
# 2                217000000    8.336460        217000000
# 3                 21000000    7.322219         21000000
# 6                 13000000    7.113943         13000000
# 7                 18000000    7.255273         18000000
# ...                    ...         ...              ...
# 99993             50000000    7.698970         50000000
# 99996             15000000    7.176091         15000000
# 99997             20000000    7.301030         20000000
# 99998             22000000    7.342423         22000000
# 100000            42000000    7.623249         42000000
#
# [80909 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
t = data.loc[:, ["OriginResponseTime", "ClientDeviceType", "ClientCountry"]]
plt.scatter(x=t["OriginResponseTime"], y= t["ClientCountry"])

# %%
ts_cols = ['EdgeStartTimestamp', 'EdgeEndTimestamp']
ts = []

for col in ts_cols:
    ts.append(pd.to_datetime(data.loc[:, col]))

ts = pd.DataFrame(ts).transpose()

# %%
ts.loc[:,'Diff'] = (ts.EdgeEndTimestamp - ts.EdgeStartTimestamp)

# %%
ts.loc[:,'Diff'].apply(lambda x: x.seconds*1000)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 99996     0
# 99997     0
# 99998     0
# 99999     0
# 100000    0
# Name: Diff, Length: 100001, dtype: int64

# %%
ts
# Out:
#         EdgeStartTimestamp    EdgeEndTimestamp   Diff
# 0      2020-01-17 00:00:00 2020-01-17 00:00:00 0 days
# 1      2020-01-16 23:59:17 2020-01-16 23:59:17 0 days
# 2      2020-01-16 23:59:59 2020-01-16 23:59:59 0 days
# 3      2020-01-16 23:59:12 2020-01-16 23:59:12 0 days
# 4      2020-01-16 23:59:17 2020-01-16 23:59:17 0 days
# ...                    ...                 ...    ...
# 99996  2020-01-17 14:15:53 2020-01-17 14:15:53 0 days
# 99997  2020-01-17 14:15:33 2020-01-17 14:15:33 0 days
# 99998  2020-01-17 14:15:26 2020-01-17 14:15:26 0 days
# 99999  2020-01-17 14:15:10 2020-01-17 14:15:10 0 days
# 100000 2020-01-17 14:15:04 2020-01-17 14:15:04 0 days
#
# [100001 rows x 3 columns]

# %%
[d for d in data.columns if 'Time' in d]
# Out:
# ['EdgeEndTimestamp',
#  'EdgeStartTimestamp',
#  'OriginResponseTime',
#  'WorkerCPUTime']

# %%
def create_target_report_gleb(target, target_col):

    f, axes = plt.subplots(nrows=2)
    f.suptitle(target_col)
    
    _1 = axes[0].plot(target.loc[:, target_col])
    _2 = axes[1].hist(target.loc[:, target_col])

    return _1

# %%
plot_gleb = create_target_report_gleb(data, report_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-682281e53d1b> in <module>
# ----> 1 plot_gleb = create_target_report_gleb(data, report_id)
#
# NameError: name 'report_id' is not defined

# %%
report_id = 'OriginResponseTime'
data = loader_raw_lines(data_file, 50)

# %%
create_target_report(data,'OriginResponseTime')
